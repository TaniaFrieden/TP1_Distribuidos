# %%
import importlib
import utils.obtener_queries as obtener_queries_module
from utils.comparar_datasets import comparar_csv_sin_orden
from utils.titular import imprimir_titulo


ACTUAL_TEMPLATE = "../output/output_{q}.csv"
EXPECTED_TEMPLATE = "./query{q}/q{q}_solucion.csv"

CANTIDAD_EJECUCIONES = 10

obtener_queries_module = importlib.reload(obtener_queries_module)
QUERIES = obtener_queries_module.obtener_queries_desde_compose()
fallas_por_query = {q: 0 for q in QUERIES}

for indice in range(1, CANTIDAD_EJECUCIONES + 1):
    imprimir_titulo(f"Iteración {indice}/{CANTIDAD_EJECUCIONES}")
    
    # !make -C .. client

    for query in QUERIES:
        actual_csv = ACTUAL_TEMPLATE.format(q=query)        
        expected_csv = EXPECTED_TEMPLATE.format(q=query)
        print(f"\nComparando CSVs para Query {query}:")
        son_iguales, mensaje = comparar_csv_sin_orden(actual_csv, expected_csv)
        print(mensaje)

        if son_iguales:
            print("Resultado notebook: iguales")
            continue

        fallas_por_query[query] += 1
        print("Resultado notebook: diferentes")

imprimir_titulo("Resumen")

print("\nResumen de fallas por query:")
for query, fallas in fallas_por_query.items():
    print(f"Query {query}: {fallas} fallas en {CANTIDAD_EJECUCIONES} ejecuciones")
# Out:
# ==================================================
#                   Iteración 1/1
# ==================================================
# make: se entra en el directorio '/home/san/Documentos/FACULTAD/DISTRIBUIDOS/TP1_Distribuidos'
# TRANSACTIONS_FILE=datasets/transacciones_sample.csv \
# ACCOUNTS_FILE=datasets/accounts_sample.csv \
# OUTPUT_DIR=output \
# SERVER_HOST=127.0.0.1 \
# SERVER_PORT=5678 \
# BATCH_SIZE=10000 \
# PYTHONPATH=src .venv/bin/python src/client/client.py
# 2026-05-26 19:31:07,800 INFO [root] Conectado a 127.0.0.1:5678
# 2026-05-26 19:31:07,800 INFO [root] Cliente iniciado con ID: 8fbc9d9c-3982-4f95-b072-0986ee5c318e
# 2026-05-26 19:31:07,801 INFO [root] Hilo receptor activo: Esperando reportes...
# 2026-05-26 19:31:07,801 INFO [root] Iniciando envío dinámico desde datasets/transacciones_sample.csv para client_id 8fbc9d9c-3982-4f95-b072-0986ee5c318e
# 2026-05-26 19:31:07,802 INFO [root] Iniciando envío dinámico desde datasets/accounts_sample.csv para client_id 8fbc9d9c-3982-4f95-b072-0986ee5c318e
# 2026-05-26 19:31:07,854 INFO [root] Envío de datasets/accounts_sample.csv finalizado.
# 2026-05-26 19:31:08,030 INFO [root] Envío de datasets/transacciones_sample.csv finalizado.
# 2026-05-26 19:31:08,030 INFO [root] Señal global de END_OF_RECODS enviada.
# 2026-05-26 19:31:08,092 INFO [root] [QUERY 1] Inicio de recepción de resultados.
# 2026-05-26 19:31:13,400 INFO [root] EOF recibido para query 1
# 2026-05-26 19:31:13,401 INFO [root] [QUERY 1] Finalizada en 5.308 s
# 2026-05-26 19:31:13,401 INFO [root] Proceso terminado.
# 2026-05-26 19:31:13,402 INFO [root] Cliente finalizado en 5.602 s
# make: se sale del directorio '/home/san/Documentos/FACULTAD/DISTRIBUIDOS/TP1_Distribuidos'
#
# Comparando CSVs para Query 1:
# ¡Los archivos CSV son exactamente IGUALES! (ignorando el orden)
# Resultado notebook: iguales
#
# ==================================================
#                      Resumen
# ==================================================
#
# Resumen de fallas por query:
# Query 1: 0 fallas en 1 ejecuciones
